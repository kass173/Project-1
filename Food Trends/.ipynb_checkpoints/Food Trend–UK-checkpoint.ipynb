# %% [markdown]
# # Food Trends - UK

# %% [markdown]
# the most common food purchased and consumed by the general UK Population.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
#DataFrame

age_path = "../Resources/Exp_AGE_201819.csv"
econ_path = "../Resources/Exp_ECON_201819.csv"
eth_path = "../Resources/Exp_ETH_201819.csv"

df_age = pd.read_csv(age_path)
df_econ = pd.read_csv(econ_path)
df_eth = pd.read_csv(eth_path)

# %%
df_age.head()
# Out:
#    Survey_Year  hh_categorisation_number hh_categorisation_description  \
# 0       201819                         1                      Under 30
# 1       201819                         1                      Under 30
# 2       201819                         1                      Under 30
# 3       201819                         1                      Under 30
# 4       201819                         1                      Under 30
#
#   Food_code                  Food_Code_description  \
# 0       402                         UHT whole milk
# 1       404  Pasteurised or homogenised whole milk
# 2       901           Condensed or evaporated milk
# 3      1102  Infant or baby milks - ready to drink
# 4      1103           Infant or baby milks - dried
#
#    ew:Sum(expenditure_*_household_weight)  \
# 0                                  264.10
# 1                               193620.64
# 2                                 5211.00
# 3                                    0.00
# 4                               217879.07
#
#    ew2:Sum(expenditure_squared_*_household_weight_squared)  \
# 0                                       6.974881e+04
# 1                                       1.396411e+09
# 2                                       1.009692e+07
# 3                                       0.000000e+00
# 4                                       6.203998e+09
#
#    mw:Sum(members_of_household_*_household_weight)  \
# 0                                          5755.08
# 1                                          5755.08
# 2                                          5755.08
# 3                                          5755.08
# 4                                          5755.08
#
#    mw2:(Sum(members_of_household_squared_*_household_weight_squared)  \
# 0                                        274339.0194
# 1                                        274339.0194
# 2                                        274339.0194
# 3                                        274339.0194
# 4                                        274339.0194
#
#    ewmw:Sum(expenditure_*_weighted_number_of_household_members_*_household_weight)  \
# 0                                       1.468396e+03
# 1                                       8.305295e+06
# 2                                       4.266809e+05
# 3                                       0.000000e+00
# 4                                       1.205700e+07
#
#   Combined_hh_categorisation_and_food_code  \
# 0                                    1_402
# 1                                    1_404
# 2                                    1_901
# 3                                   1_1102
# 4                                   1_1103
#
#    Estimate_of_average_expenditure:0.5*(ew/mw)  calc1:ew2/(ew*ew)  \
# 0                                     0.022945           1.000000
# 1                                    16.821716           0.037249
# 2                                     0.452730           0.371832
# 3                                     0.000000           0.000000
# 4                                    18.929282           0.130689
#
#    calc2:ewmw/(ew*mw)  calc3:mw2/(mw*mw)  \
# 0            0.001932           0.008283
# 1            0.014907           0.008283
# 2            0.028455           0.008283
# 3            0.000000           0.008283
# 4            0.019231           0.008283
#
#    standard_error:estimate_of_average_expenditure_*_(Square_Root(calc1-calc2+calc3)  \
# 0                                           0.023018
# 1                                           2.943793
# 2                                           0.268473
# 3                                           0.000000
# 4                                           6.550227
#
#    residual_standard_error:standard_error_*_100/Estimate_of_average_expenditure
# 0                                         100.317034
# 1                                          17.499955
# 2                                          59.300927
# 3                                           0.000000
# 4                                          34.603673

# %%
# columns to be cleaned

Survey_Year
hh_categorisation_number
ew2:Sum(expenditure_squared_*_household_weight_squared)
mw:Sum(members_of_household_*_household_weight)
mw2:(Sum(members_of_household_squared_*_household_weight_squared)
ewmw:Sum(expenditure_*_weighted_number_of_household_members_*_household_weight)
     
     
(Sum(members_of_household_squared_*_household_weight_squared)
ewmw:Sum(expenditure_*_weighted_number_of_household_members_*_household_weight)
Combined_hh_categorisation_and_food_code

# %%
#1. What is the most popular food by the Age groups - top 5

popular_food_by_age = cleandf.groupby(["Food Group"]).count() ["Total Amount Consumed"]

plot_pandas = popular_food_by_age.plot.bar(figsize=(6,6), color='b',fontsize = 11)
popular_food_by_age
plt.xlabel("Food Group",fontsize = 8)
plt.ylabel("Total Amount Consumed",fontsize = 8)
plt.title("Popular Foods By Age Group",fontsize = 14)

plt.savefig("../Images/Popular Foods By Age Group.png", bbox_inches = "tight")
plt.tight_layout()
plt.show()

popular_food_by_age

# %%
#2. What is the most common food purchased by differant ethnic groups

# %%
#3. Food trend by Socio Economic groups (Part time, Full Time, Unemployed, Retired)

# %%
#4. Food Consumption by Age

# %%
#5. Spend on food by Age Group

# %%
# Most Purchase Foods across all groups

# %%
# Least Purchase Foods across all groups

# %%
#Summaries ..... Most pupalr food group across every single socio economic group
